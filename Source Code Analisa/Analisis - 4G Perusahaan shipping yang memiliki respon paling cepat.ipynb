# %%
import pandas as pd

# orderdetailsdf = pd.read_excel(r'Order Details.xlsx')
ordersdf = pd.read_excel(r'Orders.xlsx')

ordersdf.head()
# Out:
#    Order ID                   Customer           Employee Order Date  \
# 0     10248  Vins et alcools Chevalier   Buchanan, Steven 1994-08-04
# 1     10249         Toms Spezialitäten    Suyama, Michael 1994-08-05
# 2     10250              Hanari Carnes  Peacock, Margaret 1994-08-08
# 3     10251       Victuailles en stock   Leverling, Janet 1994-08-08
# 4     10252           Suprêmes délices  Peacock, Margaret 1994-08-09
#
#   Required Date Shipped Date          Ship Via  Freight  \
# 0    1994-09-01   1994-08-16  Federal Shipping    32.38
# 1    1994-09-16   1994-08-10    Speedy Express    11.61
# 2    1994-09-05   1994-08-12    United Package    65.83
# 3    1994-09-05   1994-08-15    Speedy Express    41.34
# 4    1994-09-06   1994-08-11    United Package    51.30
#
#                    Ship Name          Ship Address       Ship City  \
# 0  Vins et alcools Chevalier    59 rue de l'Abbaye           Reims
# 1         Toms Spezialitäten         Luisenstr. 48         Münster
# ...

# %%
ordersdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 830 entries, 0 to 829
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          830 non-null    int64
#  1   Customer          830 non-null    object
#  2   Employee          830 non-null    object
#  3   Order Date        830 non-null    datetime64[ns]
#  4   Required Date     830 non-null    datetime64[ns]
#  5   Shipped Date      809 non-null    datetime64[ns]
#  6   Ship Via          830 non-null    object
#  7   Freight           830 non-null    float64
#  8   Ship Name         830 non-null    object
#  9   Ship Address      830 non-null    object
#  10  Ship City         830 non-null    object
#  11  Ship Region       323 non-null    object
#  12  Ship Postal Code  811 non-null    object
#  13  Ship Country      830 non-null    object
# dtypes: datetime64[ns](3), float64(1), int64(1), object(9)
# memory usage: 90.9+ KB

# %%
ordersdf.dropna(subset = ["Shipped Date"], inplace=True)

# %%
ordersdf
# Out:
#      Order ID                      Customer           Employee Order Date  \
# 0       10248     Vins et alcools Chevalier   Buchanan, Steven 1994-08-04
# 1       10249            Toms Spezialitäten    Suyama, Michael 1994-08-05
# 2       10250                 Hanari Carnes  Peacock, Margaret 1994-08-08
# 3       10251          Victuailles en stock   Leverling, Janet 1994-08-08
# 4       10252              Suprêmes délices  Peacock, Margaret 1994-08-09
# ..        ...                           ...                ...        ...
# 815     11063  Hungry Owl All-Night Grocers   Leverling, Janet 1996-05-30
# 816     11064            Save-a-lot Markets     Davolio, Nancy 1996-05-31
# 818     11066          White Clover Markets       King, Robert 1996-05-31
# 819     11067      Drachenblut Delikatessen     Davolio, Nancy 1996-06-03
# 821     11069           Tortuga Restaurante     Davolio, Nancy 1996-06-03
#
#     Required Date Shipped Date          Ship Via  Freight  \
# ...

# %%
import numpy as np
ordersdf['diff_days'] = ordersdf['Shipped Date'] - ordersdf['Order Date']

ordersdf['diff_days'] = ordersdf['diff_days'] / np.timedelta64(1,'D')

# %%
# ordersdf['Order Date'] = ordersdf['Order Date'].dt.strftime('%Y')
# ordersdf['Shipped Date'] = ordersdf['Shipped Date'].dt.strftime('%Y')

# %%
ordersdf
# Out:
#      Order ID                      Customer           Employee Order Date  \
# 0       10248     Vins et alcools Chevalier   Buchanan, Steven 1994-08-04
# 1       10249            Toms Spezialitäten    Suyama, Michael 1994-08-05
# 2       10250                 Hanari Carnes  Peacock, Margaret 1994-08-08
# 3       10251          Victuailles en stock   Leverling, Janet 1994-08-08
# 4       10252              Suprêmes délices  Peacock, Margaret 1994-08-09
# ..        ...                           ...                ...        ...
# 815     11063  Hungry Owl All-Night Grocers   Leverling, Janet 1996-05-30
# 816     11064            Save-a-lot Markets     Davolio, Nancy 1996-05-31
# 818     11066          White Clover Markets       King, Robert 1996-05-31
# 819     11067      Drachenblut Delikatessen     Davolio, Nancy 1996-06-03
# 821     11069           Tortuga Restaurante     Davolio, Nancy 1996-06-03
#
#     Required Date Shipped Date          Ship Via  Freight  \
# ...

# %%
ordersdf2 = ordersdf.groupby(by=['Ship Via'], sort=False, as_index=False)['diff_days'].sum()
ordersdf2
# Out:
#            Ship Via  diff_days
# 0  Federal Shipping     1861.0
# 1    Speedy Express     2100.0
# 2    United Package     2909.0

# %%
ordersdf[ordersdf['Ship Via'] == 'Federal Shipping']
# Out:
#      Order ID                    Customer           Employee Order Date  \
# 0       10248   Vins et alcools Chevalier   Buchanan, Steven 1994-08-04
# 7       10255          Richter Supermarkt    Dodsworth, Anne 1994-08-12
# 9       10257            HILARIÓN-Abastos  Peacock, Margaret 1994-08-16
# 11      10259  Centro comercial Moctezuma  Peacock, Margaret 1994-08-18
# 14      10262  Rattlesnake Canyon Grocery    Callahan, Laura 1994-08-22
# ..        ...                         ...                ...        ...
# 785     11033          Richter Supermarkt       King, Robert 1996-05-17
# 788     11036    Drachenblut Delikatessen    Callahan, Laura 1996-05-20
# 799     11047          Eastern Connection       King, Robert 1996-05-24
# 800     11048       Bottom-Dollar Markets       King, Robert 1996-05-24
# 809     11057                 North/South   Leverling, Janet 1996-05-29
#
#     Required Date Shipped Date          Ship Via  Freight  \
# ...

# %%
Average = 1861.0/249
Average
# Out:
# 7.473895582329317

# %%
ordersdf[ordersdf['Ship Via'] == 'Speedy Express']
# Out:
#      Order ID              Customer           Employee Order Date  \
# 1       10249    Toms Spezialitäten    Suyama, Michael 1994-08-05
# 3       10251  Victuailles en stock   Leverling, Janet 1994-08-08
# 10      10258          Ernst Handel     Davolio, Nancy 1994-08-17
# 12      10260    Ottilies Käseladen  Peacock, Margaret 1994-08-19
# 17      10265  Blondel père et fils     Fuller, Andrew 1994-08-25
# ..        ...                   ...                ...        ...
# 794     11042      Comércio Mineiro     Fuller, Andrew 1996-05-22
# 796     11044        Wolski  Zajazd  Peacock, Margaret 1996-05-23
# 801     11049   Gourmet Lanchonetes   Leverling, Janet 1996-05-24
# 804     11052         Hanari Carnes   Leverling, Janet 1996-05-27
# 816     11064    Save-a-lot Markets     Davolio, Nancy 1996-05-31
#
#     Required Date Shipped Date        Ship Via  Freight             Ship Name  \
# 1      1994-09-16   1994-08-10  Speedy Express    11.61    Toms Spezialitäten
# ...

# %%
Average = 2100.0/245
Average
# Out:
# 8.571428571428571

# %%
ordersdf[ordersdf['Ship Via'] == 'United Package']
# Out:
#      Order ID                      Customer           Employee Order Date  \
# 2       10250                 Hanari Carnes  Peacock, Margaret 1994-08-08
# 4       10252              Suprêmes délices  Peacock, Margaret 1994-08-09
# 5       10253                 Hanari Carnes   Leverling, Janet 1994-08-10
# 6       10254             Chop-suey Chinese   Buchanan, Steven 1994-08-11
# 8       10256        Wellington Importadora   Leverling, Janet 1994-08-15
# ..        ...                           ...                ...        ...
# 812     11060                Franchi S.p.A.     Fuller, Andrew 1996-05-30
# 815     11063  Hungry Owl All-Night Grocers   Leverling, Janet 1996-05-30
# 818     11066          White Clover Markets       King, Robert 1996-05-31
# 819     11067      Drachenblut Delikatessen     Davolio, Nancy 1996-06-03
# 821     11069           Tortuga Restaurante     Davolio, Nancy 1996-06-03
#
#     Required Date Shipped Date        Ship Via  Freight  \
# ...

# %%
Average = 2909.0/315
Average
# Out:
# 9.234920634920634

# %% [markdown]
# ### Rata-rata waktu tunggu barang dari permintaan (Order) sampai dikirimkan (Shipped):
# ### Federal Shipping: 7.47 hari.
# ### Speedy Express: 8.57 hari.
# ### United Package: 9.23 hari.
#
# ### Dapat dilihat bahwa Federal Shipping dapat merespon paket dengan lebih cepat.
